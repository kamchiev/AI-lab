# %%
from numpy import nan
import numpy as np
from sklearn.impute import SimpleImputer #helps to fill the missing data

# %%
X = np.array([
    [nan,0,3],
    [3,5,2],
    [7,9,nan]
])

y= np.array([14,16,8])

# %%
Imputer = SimpleImputer(strategy="mean")
X2 = Imputer.fit_transform(X)

print(X2)
# Out:
# [[5.  0.  3. ]
#  [3.  5.  2. ]
#  [7.  9.  2.5]]
